# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # pause for 1 second using time.sleep() - avoids the Openweather API key from being disabled
        time.sleep(1)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | happy valley-goose bay
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | vorgashor
# Processing Record 4 of Set 1 | kyaikkami
# Processing Record 5 of Set 1 | papatowai
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | tommot
# Processing Record 8 of Set 1 | lijiang
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | waiuku
# Processing Record 12 of Set 1 | grytviken
# Processing Record 13 of Set 1 | praia da vitoria
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | namibe
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | inirida
# Processing Record 20 of Set 1 | nuuk
# Processing Record 21 of Set 1 | tual
# Processing Record 22 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 1 | karaidel'
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | qarazhal
# Processing Record 26 of Set 1 | hovd
# Processing Record 27 of Set 1 | burao
# Processing Record 28 of Set 1 | chelak
# Processing Record 29 of Set 1 | itapirapua
# Processing Record 30 of Set 1 | keflavik
# Processing Record 31 of Set 1 | tolanaro
# Processing Record 32 of Set 1 | edinburgh of the seven seas
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | kenai
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | mugia
# Processing Record 37 of Set 1 | chumphon
# Processing Record 38 of Set 1 | adamstown
# Processing Record 39 of Set 1 | bo phloi
# Processing Record 40 of Set 1 | gadzhiyevo
# Processing Record 41 of Set 1 | shushenskoye
# Processing Record 42 of Set 1 | khandyga
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | waat
# Processing Record 45 of Set 1 | luuq
# Processing Record 46 of Set 1 | selibaby
# Processing Record 47 of Set 1 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 48 of Set 1 | yambio
# Processing Record 49 of Set 1 | zyryanovsk
# Processing Record 50 of Set 1 | haiku-pauwela
# Processing Record 0 of Set 2 | port-aux-francais
# Processing Record 1 of Set 2 | pendleton
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | aparecida de goiania
# Processing Record 4 of Set 2 | margaret river
# Processing Record 5 of Set 2 | saint-joseph
# Processing Record 6 of Set 2 | lihue
# Processing Record 7 of Set 2 | vangaindrano
# Processing Record 8 of Set 2 | rotonda west
# Processing Record 9 of Set 2 | glace bay
# Processing Record 10 of Set 2 | afaahiti
# Processing Record 11 of Set 2 | badger
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | fortaleza
# Processing Record 14 of Set 2 | sangin
# Processing Record 15 of Set 2 | port saint john's
# Processing Record 16 of Set 2 | buk
# Processing Record 17 of Set 2 | stanley
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | puerto natales
# Processing Record 20 of Set 2 | taltal
# Processing Record 21 of Set 2 | tadine
# Processing Record 22 of Set 2 | papao
# Processing Record 23 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 24 of Set 2 | lautoka
# Processing Record 25 of Set 2 | cocieri
# Processing Record 26 of Set 2 | olonkinbyen
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | ceres
# Processing Record 29 of Set 2 | sterling
# Processing Record 30 of Set 2 | samamea
# City not found. Skipping...
# Processing Record 31 of Set 2 | saipan
# Processing Record 32 of Set 2 | wailua homesteads
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | yatou
# Processing Record 36 of Set 2 | akjoujt
# Processing Record 37 of Set 2 | sault ste. marie
# Processing Record 38 of Set 2 | vilyuchinsk
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | chos malal
# Processing Record 41 of Set 2 | invercargill
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | kalabo
# Processing Record 44 of Set 2 | mount isa
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | estacion coahuila
# Processing Record 47 of Set 2 | vilanova i la geltru
# Processing Record 48 of Set 2 | robertsport
# Processing Record 49 of Set 2 | sarupathar
# Processing Record 0 of Set 3 | anadyr
# Processing Record 1 of Set 3 | college
# Processing Record 2 of Set 3 | el porvenir
# Processing Record 3 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 4 of Set 3 | anshun
# Processing Record 5 of Set 3 | yuzhno-kurilsk
# Processing Record 6 of Set 3 | mournies
# Processing Record 7 of Set 3 | hawaiian paradise park
# Processing Record 8 of Set 3 | soio
# Processing Record 9 of Set 3 | tofol
# Processing Record 10 of Set 3 | mulayjah
# Processing Record 11 of Set 3 | talagang
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | rio grande
# Processing Record 14 of Set 3 | aasiaat
# Processing Record 15 of Set 3 | phan rang-thap cham
# Processing Record 16 of Set 3 | akureyri
# Processing Record 17 of Set 3 | kindu
# Processing Record 18 of Set 3 | shizunai-furukawacho
# Processing Record 19 of Set 3 | sitka
# Processing Record 20 of Set 3 | bastia
# Processing Record 21 of Set 3 | quellon
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | amga
# Processing Record 25 of Set 3 | lagunas
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | kurumkan
# Processing Record 29 of Set 3 | tingi
# Processing Record 30 of Set 3 | padam
# City not found. Skipping...
# Processing Record 31 of Set 3 | concepcion
# Processing Record 32 of Set 3 | puerto leguizamo
# Processing Record 33 of Set 3 | spring valley
# Processing Record 34 of Set 3 | plouzane
# Processing Record 35 of Set 3 | santa terezinha
# Processing Record 36 of Set 3 | mega
# Processing Record 37 of Set 3 | klyuchi
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | ust-nera
# Processing Record 40 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 3 | tazovsky
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | puerto san jose
# Processing Record 44 of Set 3 | fuglafjordur
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | eirunepe
# Processing Record 47 of Set 3 | portland
# Processing Record 48 of Set 3 | bayville
# Processing Record 49 of Set 3 | blackmans bay
# Processing Record 0 of Set 4 | glubokoye
# Processing Record 1 of Set 4 | tralee
# Processing Record 2 of Set 4 | robore
# Processing Record 3 of Set 4 | sydney
# Processing Record 4 of Set 4 | rabigh
# Processing Record 5 of Set 4 | st. john's
# Processing Record 6 of Set 4 | howrah
# Processing Record 7 of Set 4 | selkirk
# Processing Record 8 of Set 4 | bikenibeu village
# Processing Record 9 of Set 4 | vadso
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | thakhek
# Processing Record 12 of Set 4 | kedainiai
# Processing Record 13 of Set 4 | port mathurin
# Processing Record 14 of Set 4 | ponta delgada
# Processing Record 15 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 4 | kobelyaky
# Processing Record 17 of Set 4 | noumea
# Processing Record 18 of Set 4 | uturoa
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | at taj
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | beledweyne
# Processing Record 23 of Set 4 | shulan
# Processing Record 24 of Set 4 | tromso
# Processing Record 25 of Set 4 | lubang
# Processing Record 26 of Set 4 | nuriootpa
# Processing Record 27 of Set 4 | pinheiro machado
# Processing Record 28 of Set 4 | khovd
# Processing Record 29 of Set 4 | sayalkudi
# Processing Record 30 of Set 4 | santa elena de uairen
# Processing Record 31 of Set 4 | atafu village
# Processing Record 32 of Set 4 | opuwo
# Processing Record 33 of Set 4 | ocean shores
# Processing Record 34 of Set 4 | isafjordur
# Processing Record 35 of Set 4 | levuka
# Processing Record 36 of Set 4 | robit
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | schuyler
# Processing Record 39 of Set 4 | udachny
# Processing Record 40 of Set 4 | sishilichengzi
# City not found. Skipping...
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | annau
# Processing Record 43 of Set 4 | north bend
# Processing Record 44 of Set 4 | castelli
# Processing Record 45 of Set 4 | narvik
# Processing Record 46 of Set 4 | borshchiv
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | enewetak
# Processing Record 49 of Set 4 | ancud
# Processing Record 0 of Set 5 | taoudenni
# Processing Record 1 of Set 5 | colares
# Processing Record 2 of Set 5 | kingston
# Processing Record 3 of Set 5 | port alfred
# Processing Record 4 of Set 5 | kerikeri
# Processing Record 5 of Set 5 | iwanai
# Processing Record 6 of Set 5 | la arena
# Processing Record 7 of Set 5 | yarmouth
# Processing Record 8 of Set 5 | rondonopolis
# Processing Record 9 of Set 5 | berezovyy
# Processing Record 10 of Set 5 | kashary
# Processing Record 11 of Set 5 | miles city
# Processing Record 12 of Set 5 | labrador city
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | west island
# Processing Record 15 of Set 5 | kamloops
# Processing Record 16 of Set 5 | leeton
# Processing Record 17 of Set 5 | dwarka
# Processing Record 18 of Set 5 | cuyo
# Processing Record 19 of Set 5 | viedma
# Processing Record 20 of Set 5 | dudinka
# Processing Record 21 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 22 of Set 5 | la plata
# Processing Record 23 of Set 5 | nova sintra
# Processing Record 24 of Set 5 | san rafael
# Processing Record 25 of Set 5 | biharamulo
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | argo
# Processing Record 28 of Set 5 | faya-largeau
# Processing Record 29 of Set 5 | orlu
# Processing Record 30 of Set 5 | ljusdal
# Processing Record 31 of Set 5 | abepura
# Processing Record 32 of Set 5 | ma'rib
# Processing Record 33 of Set 5 | kristiansund
# Processing Record 34 of Set 5 | coquimbo
# Processing Record 35 of Set 5 | ketchikan
# Processing Record 36 of Set 5 | mammoth lakes
# Processing Record 37 of Set 5 | konarka
# Processing Record 38 of Set 5 | san antonio de pale
# Processing Record 39 of Set 5 | tosontsengel
# Processing Record 40 of Set 5 | susuman
# Processing Record 41 of Set 5 | tabas
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | val-d'or
# Processing Record 44 of Set 5 | byron bay
# Processing Record 45 of Set 5 | terra nova
# Processing Record 46 of Set 5 | kawthoung
# City not found. Skipping...
# Processing Record 47 of Set 5 | auki
# Processing Record 48 of Set 5 | mwinilunga
# Processing Record 49 of Set 5 | knyaze-volkonskoye
# Processing Record 0 of Set 6 | kapa'a
# Processing Record 1 of Set 6 | lazaro cardenas
# Processing Record 2 of Set 6 | daru
# Processing Record 3 of Set 6 | dryden
# Processing Record 4 of Set 6 | utrik
# Processing Record 5 of Set 6 | sisimiut
# Processing Record 6 of Set 6 | feijo
# Processing Record 7 of Set 6 | pierre
# Processing Record 8 of Set 6 | takoradi
# Processing Record 9 of Set 6 | shalqar
# Processing Record 10 of Set 6 | maracay
# Processing Record 11 of Set 6 | newman
# Processing Record 12 of Set 6 | prince rupert
# Processing Record 13 of Set 6 | pacific grove
# Processing Record 14 of Set 6 | musoma
# Processing Record 15 of Set 6 | torghay
# Processing Record 16 of Set 6 | kostomuksha
# Processing Record 17 of Set 6 | sikonge
# Processing Record 18 of Set 6 | el calafate
# Processing Record 19 of Set 6 | dalandzadgad
# Processing Record 20 of Set 6 | ust'-ilimsk
# Processing Record 21 of Set 6 | oyama
# Processing Record 22 of Set 6 | funafuti
# Processing Record 23 of Set 6 | malvan
# Processing Record 24 of Set 6 | kurchatov
# Processing Record 25 of Set 6 | fuxin
# Processing Record 26 of Set 6 | alice springs
# Processing Record 27 of Set 6 | cameta
# Processing Record 28 of Set 6 | broome
# Processing Record 29 of Set 6 | fale old settlement
# Processing Record 30 of Set 6 | riviere-du-loup
# Processing Record 31 of Set 6 | jiuquan
# Processing Record 32 of Set 6 | miracema do tocantins
# Processing Record 33 of Set 6 | iskateley
# Processing Record 34 of Set 6 | devils lake
# Processing Record 35 of Set 6 | pochinki
# Processing Record 36 of Set 6 | ape
# Processing Record 37 of Set 6 | nadym
# Processing Record 38 of Set 6 | naze
# Processing Record 39 of Set 6 | bardai
# Processing Record 40 of Set 6 | boden
# Processing Record 41 of Set 6 | tan-tan
# Processing Record 42 of Set 6 | mejit
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | thompson
# Processing Record 45 of Set 6 | weno
# Processing Record 46 of Set 6 | santa ana
# Processing Record 47 of Set 6 | satka
# Processing Record 48 of Set 6 | el galpon
# Processing Record 49 of Set 6 | yeed
# Processing Record 0 of Set 7 | egilsstadir
# Processing Record 1 of Set 7 | kaohsiung
# Processing Record 2 of Set 7 | san patricio
# Processing Record 3 of Set 7 | konya
# Processing Record 4 of Set 7 | karatau
# Processing Record 5 of Set 7 | duba
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | constantia
# Processing Record 9 of Set 7 | fada
# Processing Record 10 of Set 7 | nar'yan-mar
# Processing Record 11 of Set 7 | urzhar
# Processing Record 12 of Set 7 | la sarre
# Processing Record 13 of Set 7 | crane
# Processing Record 14 of Set 7 | valparaiso
# Processing Record 15 of Set 7 | dauphin
# Processing Record 16 of Set 7 | faaborg
# Processing Record 17 of Set 7 | vilyuysk
# Processing Record 18 of Set 7 | ulladulla
# Processing Record 19 of Set 7 | port hedland
# Processing Record 20 of Set 7 | kayangel
# Processing Record 21 of Set 7 | framingham center
# Processing Record 22 of Set 7 | kharkhorin
# Processing Record 23 of Set 7 | avanigadda
# Processing Record 24 of Set 7 | bac lieu
# Processing Record 25 of Set 7 | oualidia
# City not found. Skipping...
# Processing Record 26 of Set 7 | acarau
# Processing Record 27 of Set 7 | khilok
# Processing Record 28 of Set 7 | sinop
# Processing Record 29 of Set 7 | port augusta
# Processing Record 30 of Set 7 | rantepao
# Processing Record 31 of Set 7 | inekar
# City not found. Skipping...
# Processing Record 32 of Set 7 | lonavla
# Processing Record 33 of Set 7 | mabaruma
# Processing Record 34 of Set 7 | brigantine
# Processing Record 35 of Set 7 | port douglas
# Processing Record 36 of Set 7 | minab
# Processing Record 37 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 7 | trinity beach
# Processing Record 39 of Set 7 | severobaykal'sk
# Processing Record 40 of Set 7 | camana
# Processing Record 41 of Set 7 | wrzesnia
# Processing Record 42 of Set 7 | yakeshi
# Processing Record 43 of Set 7 | xuanzhou
# Processing Record 44 of Set 7 | muli
# Processing Record 45 of Set 7 | stephenville
# Processing Record 46 of Set 7 | kidal
# Processing Record 47 of Set 7 | arvayheer
# Processing Record 48 of Set 7 | kouango
# Processing Record 49 of Set 7 | peace river
# Processing Record 0 of Set 8 | ao luek
# Processing Record 1 of Set 8 | tejen
# Processing Record 2 of Set 8 | tidjikja
# Processing Record 3 of Set 8 | beloretsk
# Processing Record 4 of Set 8 | buala
# Processing Record 5 of Set 8 | sumenep
# Processing Record 6 of Set 8 | geraldton
# Processing Record 7 of Set 8 | nebbi
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | ouarzazat
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | bou arada
# Processing Record 12 of Set 8 | trincomalee
# Processing Record 13 of Set 8 | saint-philippe
# Processing Record 14 of Set 8 | mandalgarh
# Processing Record 15 of Set 8 | petawawa
# Processing Record 16 of Set 8 | arraial do cabo
# Processing Record 17 of Set 8 | mildura
# Processing Record 18 of Set 8 | mansa
# Processing Record 19 of Set 8 | mount pearl
# Processing Record 20 of Set 8 | labytnangi
# Processing Record 21 of Set 8 | sarina
# Processing Record 22 of Set 8 | kyzyl-burun
# City not found. Skipping...
# Processing Record 23 of Set 8 | dadukou
# Processing Record 24 of Set 8 | vernon
# Processing Record 25 of Set 8 | rohru
# Processing Record 26 of Set 8 | luis correia
# Processing Record 27 of Set 8 | as sulayyil
# Processing Record 28 of Set 8 | ar ruseris
# Processing Record 29 of Set 8 | ugoofaaru
# Processing Record 30 of Set 8 | fortuna
# Processing Record 31 of Set 8 | tarakan
# Processing Record 32 of Set 8 | salinas
# Processing Record 33 of Set 8 | puerto lempira
# Processing Record 34 of Set 8 | northam
# Processing Record 35 of Set 8 | horta
# Processing Record 36 of Set 8 | villa gesell
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | conception bay south
# Processing Record 39 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 40 of Set 8 | tomatlan
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | key west
# Processing Record 43 of Set 8 | ashgabat
# Processing Record 44 of Set 8 | parun
# Processing Record 45 of Set 8 | majene
# Processing Record 46 of Set 8 | les cayes
# Processing Record 47 of Set 8 | fort mcmurray
# Processing Record 48 of Set 8 | vorkuta
# Processing Record 49 of Set 8 | quepos
# Processing Record 0 of Set 9 | viamao
# Processing Record 1 of Set 9 | tumpat
# Processing Record 2 of Set 9 | chibougamau
# Processing Record 3 of Set 9 | bayganin
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | surgeres
# Processing Record 6 of Set 9 | kotlas
# Processing Record 7 of Set 9 | polyarnyy
# Processing Record 8 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 9 of Set 9 | goba
# Processing Record 10 of Set 9 | dhuusamarreeb
# Processing Record 11 of Set 9 | yulinshi
# Processing Record 12 of Set 9 | salaberry-de-valleyfield
# Processing Record 13 of Set 9 | mersing
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | dhalie
# Processing Record 16 of Set 9 | sinabang
# Processing Record 17 of Set 9 | bubaque
# Processing Record 18 of Set 9 | ariquemes
# Processing Record 19 of Set 9 | kuching
# Processing Record 20 of Set 9 | bonthe
# Processing Record 21 of Set 9 | kardla
# Processing Record 22 of Set 9 | ihosy
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | lahaina
# Processing Record 25 of Set 9 | el granada
# Processing Record 26 of Set 9 | zaozersk
# Processing Record 27 of Set 9 | tezu
# Processing Record 28 of Set 9 | bawku
# Processing Record 29 of Set 9 | castillos
# Processing Record 30 of Set 9 | jiwani
# Processing Record 31 of Set 9 | pluzine
# City not found. Skipping...
# Processing Record 32 of Set 9 | mananjary
# Processing Record 33 of Set 9 | trenggalek
# Processing Record 34 of Set 9 | rustington
# Processing Record 35 of Set 9 | fargo
# Processing Record 36 of Set 9 | ujae
# Processing Record 37 of Set 9 | vallegrande
# Processing Record 38 of Set 9 | verkhnevilyuysk
# Processing Record 39 of Set 9 | puntarenas
# Processing Record 40 of Set 9 | acheng
# Processing Record 41 of Set 9 | maxixe
# Processing Record 42 of Set 9 | hilo
# Processing Record 43 of Set 9 | khorixas
# Processing Record 44 of Set 9 | doka
# Processing Record 45 of Set 9 | cabo san lucas
# Processing Record 46 of Set 9 | buka
# Processing Record 47 of Set 9 | richards bay
# Processing Record 48 of Set 9 | belyy yar
# Processing Record 49 of Set 9 | cam pha mines
# Processing Record 0 of Set 10 | plastun
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | rechytsa
# Processing Record 3 of Set 10 | ishigaki
# Processing Record 4 of Set 10 | queenstown
# Processing Record 5 of Set 10 | kirensk
# Processing Record 6 of Set 10 | ain kercha
# Processing Record 7 of Set 10 | baise city
# Processing Record 8 of Set 10 | genhe
# Processing Record 9 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 10 of Set 10 | yichang
# Processing Record 11 of Set 10 | chonchi
# Processing Record 12 of Set 10 | sivrice
# Processing Record 13 of Set 10 | cidreira
# Processing Record 14 of Set 10 | kone
# Processing Record 15 of Set 10 | kapuskasing
# Processing Record 16 of Set 10 | lockwood
# Processing Record 17 of Set 10 | lyantor
# Processing Record 18 of Set 10 | gofitskoye
# Processing Record 19 of Set 10 | ha'il
# Processing Record 20 of Set 10 | marsh harbour
# Processing Record 21 of Set 10 | iwaki
# Processing Record 22 of Set 10 | maraba
# Processing Record 23 of Set 10 | banda aceh
# Processing Record 24 of Set 10 | novodvinsk
# Processing Record 25 of Set 10 | ceeldheer
# Processing Record 26 of Set 10 | outjo
# Processing Record 27 of Set 10 | itamaraca
# Processing Record 28 of Set 10 | la passe
# Processing Record 29 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 30 of Set 10 | port macquarie
# Processing Record 31 of Set 10 | ebon
# Processing Record 32 of Set 10 | altai
# Processing Record 33 of Set 10 | piti village
# Processing Record 34 of Set 10 | sorong
# Processing Record 35 of Set 10 | beyneu
# Processing Record 36 of Set 10 | kokshetau
# Processing Record 37 of Set 10 | wenling
# Processing Record 38 of Set 10 | isla del bosque
# Processing Record 39 of Set 10 | touros
# Processing Record 40 of Set 10 | brisas de zicatela
# Processing Record 41 of Set 10 | berezovo
# Processing Record 42 of Set 10 | acapulco de juarez
# Processing Record 43 of Set 10 | camacupa
# Processing Record 44 of Set 10 | tyukhtet
# Processing Record 45 of Set 10 | puerto baquerizo moreno
# Processing Record 46 of Set 10 | palafrugell
# Processing Record 47 of Set 10 | callao
# Processing Record 48 of Set 10 | mahibadhoo
# Processing Record 49 of Set 10 | fort st. john
# Processing Record 0 of Set 11 | baotou
# Processing Record 1 of Set 11 | harper
# Processing Record 2 of Set 11 | santa cruz
# Processing Record 3 of Set 11 | jinan
# Processing Record 4 of Set 11 | greenville
# Processing Record 5 of Set 11 | cidade velha
# Processing Record 6 of Set 11 | buga
# Processing Record 7 of Set 11 | nishinoomote
# Processing Record 8 of Set 11 | havre
# Processing Record 9 of Set 11 | ventspils
# Processing Record 10 of Set 11 | sena madureira
# Processing Record 11 of Set 11 | fort bragg
# Processing Record 12 of Set 11 | dakhla
# Processing Record 13 of Set 11 | sitia
# Processing Record 14 of Set 11 | pacasmayo
# Processing Record 15 of Set 11 | idri
# Processing Record 16 of Set 11 | ridder
# Processing Record 17 of Set 11 | coronel dorrego
# Processing Record 18 of Set 11 | maun
# Processing Record 19 of Set 11 | wynyard
# Processing Record 20 of Set 11 | pandan
# Processing Record 21 of Set 11 | tselinnoye
# Processing Record 22 of Set 11 | haikou
# Processing Record 23 of Set 11 | cabedelo
# Processing Record 24 of Set 11 | atherton
# Processing Record 25 of Set 11 | igarka
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | mariental
# Processing Record 28 of Set 11 | tanguieta
# Processing Record 29 of Set 11 | kani keli
# Processing Record 30 of Set 11 | tsumeb
# Processing Record 31 of Set 11 | bizhbulyak
# Processing Record 32 of Set 11 | pearsall
# Processing Record 33 of Set 11 | christchurch
# Processing Record 34 of Set 11 | san luis de la loma
# Processing Record 35 of Set 11 | sawakin
# Processing Record 36 of Set 11 | zhezqazghan
# Processing Record 37 of Set 11 | narragansett
# Processing Record 38 of Set 11 | nahavand
# Processing Record 39 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 40 of Set 11 | charters towers
# Processing Record 41 of Set 11 | pisco
# Processing Record 42 of Set 11 | sao vicente
# Processing Record 43 of Set 11 | trujillo
# Processing Record 44 of Set 11 | mbanza kongo
# Processing Record 45 of Set 11 | barra de santo antonio
# Processing Record 46 of Set 11 | little cayman
# City not found. Skipping...
# Processing Record 47 of Set 11 | campbellsville
# Processing Record 48 of Set 11 | luderitz
# Processing Record 49 of Set 11 | anloga
# Processing Record 0 of Set 12 | arambol
# Processing Record 1 of Set 12 | nieuw amsterdam
# Processing Record 2 of Set 12 | trumann
# Processing Record 3 of Set 12 | eagle mountain
# Processing Record 4 of Set 12 | buy
# Processing Record 5 of Set 12 | sherbakul'
# Processing Record 6 of Set 12 | chake chake
# Processing Record 7 of Set 12 | chernushka
# Processing Record 8 of Set 12 | zionsville
# Processing Record 9 of Set 12 | whangarei
# Processing Record 10 of Set 12 | remire-montjoly
# Processing Record 11 of Set 12 | poronaysk
# Processing Record 12 of Set 12 | san lorenzo de esmeraldas
# Processing Record 13 of Set 12 | ahar
# Processing Record 14 of Set 12 | mon
# Processing Record 15 of Set 12 | gladstone
# Processing Record 16 of Set 12 | porbandar
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | puerto armuelles
# Processing Record 19 of Set 12 | bagamoyo
# Processing Record 20 of Set 12 | kolonia town
# Processing Record 21 of Set 12 | archangelos
# Processing Record 22 of Set 12 | nyurba
# Processing Record 23 of Set 12 | usinsk
# Processing Record 24 of Set 12 | mil'kovo
# Processing Record 25 of Set 12 | carutapera
# Processing Record 26 of Set 12 | zangguy
# City not found. Skipping...
# Processing Record 27 of Set 12 | chicoana
# Processing Record 28 of Set 12 | humaita
# Processing Record 29 of Set 12 | parvatipuram
# Processing Record 30 of Set 12 | benjamin constant
# Processing Record 31 of Set 12 | mutoko
# Processing Record 32 of Set 12 | pimentel
# Processing Record 33 of Set 12 | anibare
# City not found. Skipping...
# Processing Record 34 of Set 12 | kabala
# Processing Record 35 of Set 12 | guarapari
# Processing Record 36 of Set 12 | oroqen zizhiqi
# Processing Record 37 of Set 12 | downpatrick
# Processing Record 38 of Set 12 | sandnessjoen
# Processing Record 39 of Set 12 | suntar
# Processing Record 40 of Set 12 | coahuayana de hidalgo
# Processing Record 41 of Set 12 | mombetsu
# Processing Record 42 of Set 12 | praia
# Processing Record 43 of Set 12 | hede
# Processing Record 44 of Set 12 | apace
# Processing Record 45 of Set 12 | nalerigu
# City not found. Skipping...
# Processing Record 46 of Set 12 | cacheu
# Processing Record 47 of Set 12 | baki
# Processing Record 48 of Set 12 | huilong
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 8 | torrington
# Processing Record 26 of Set 8 | krutikha
# Processing Record 27 of Set 8 | bonavista
# Processing Record 28 of Set 8 | zaysan
# Processing Record 29 of Set 8 | mana
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | mandera
# Processing Record 32 of Set 8 | numan
# Processing Record 33 of Set 8 | pingliang
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | honiara
# Processing Record 39 of Set 8 | pemba
# Processing Record 40 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | lerik
# Processing Record 46 of Set 8 | quelimane
# Processing Record 47 of Set 8 | katyuzhanka
# Processing Record 48 of Set 8 | narwar
# Processing Record 49 of Set 8 | port hardy
# Processing Record 0 of Set 9 | sol-iletsk
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | srednekolymsk
# Processing Record 4 of Set 9 | homer
# Processing Record 5 of Set 9 | livingston
# Processing Record 6 of Set 9 | lima
# Processing Record 7 of Set 9 | christchurch
# Processing Record 8 of Set 9 | beitbridge
# Processing Record 9 of Set 9 | kortkeros
# Processing Record 10 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 9 | port hedland
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | dicabisagan
# Processing Record 14 of Set 9 | smithers
# Processing Record 15 of Set 9 | peleduy
# Processing Record 16 of Set 9 | yulara
# Processing Record 17 of Set 9 | roebourne
# Processing Record 18 of Set 9 | mariinskiy posad
# Processing Record 19 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | ribeira grande
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | saint-francois
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | bogande
# Processing Record 31 of Set 9 | quesnel
# Processing Record 32 of Set 9 | usman
# Processing Record 33 of Set 9 | aykhal
# Processing Record 34 of Set 9 | carlyle
# Processing Record 35 of Set 9 | kayerkan
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | seoul
# Processing Record 40 of Set 9 | woodward
# Processing Record 41 of Set 9 | georgiyevskoye
# Processing Record 42 of Set 9 | mayo
# Processing Record 43 of Set 9 | kysyl-syr
# Processing Record 44 of Set 9 | tashara
# Processing Record 45 of Set 9 | acajutla
# Processing Record 46 of Set 9 | capoterra
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | maniitsoq
# Processing Record 0 of Set 10 | kalemie
# Processing Record 1 of Set 10 | tagusao
# Processing Record 2 of Set 10 | mao
# Processing Record 3 of Set 10 | mahibadhoo
# Processing Record 4 of Set 10 | cabo san lucas
# Processing Record 5 of Set 10 | panuco
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | fayaoue
# Processing Record 8 of Set 10 | stolac
# Processing Record 9 of Set 10 | gamboma
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | carutapera
# Processing Record 12 of Set 10 | port-de-bouc
# Processing Record 13 of Set 10 | nanortalik
# Processing Record 14 of Set 10 | dzaoudzi
# Processing Record 15 of Set 10 | aktau
# Processing Record 16 of Set 10 | lorengau
# Processing Record 17 of Set 10 | pachino
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | denpasar
# Processing Record 20 of Set 10 | ipixuna
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | lakki marwat
# Processing Record 24 of Set 10 | veinticinco de mayo
# Processing Record 25 of Set 10 | avdon
# Processing Record 26 of Set 10 | katobu
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | merauke
# Processing Record 29 of Set 10 | yangliuqing
# Processing Record 30 of Set 10 | tieling
# Processing Record 31 of Set 10 | togur
# Processing Record 32 of Set 10 | thinadhoo
# Processing Record 33 of Set 10 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 34 of Set 10 | terra santa
# Processing Record 35 of Set 10 | colares
# Processing Record 36 of Set 10 | havoysund
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | samandag
# Processing Record 40 of Set 10 | san joaquin
# Processing Record 41 of Set 10 | treinta y tres
# Processing Record 42 of Set 10 | nazareno
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | yaan
# Processing Record 45 of Set 10 | ixtapa
# Processing Record 46 of Set 10 | dong hoi
# Processing Record 47 of Set 10 | harindanga
# Processing Record 48 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 10 | pontypool
# Processing Record 0 of Set 11 | ulladulla
# Processing Record 1 of Set 11 | la paz
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | barroso
# Processing Record 4 of Set 11 | vryburg
# Processing Record 5 of Set 11 | beira
# Processing Record 6 of Set 11 | the valley
# Processing Record 7 of Set 11 | narsaq
# Processing Record 8 of Set 11 | juegang
# Processing Record 9 of Set 11 | verkhniy avzyan
# Processing Record 10 of Set 11 | berdyuzhye
# City not found. Skipping...
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | tautira
# Processing Record 14 of Set 11 | singkang
# Processing Record 15 of Set 11 | taitung
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | chifeng
# Processing Record 19 of Set 11 | caiaponia
# Processing Record 20 of Set 11 | salto
# Processing Record 21 of Set 11 | praya
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | abu zabad
# Processing Record 24 of Set 11 | kushima
# Processing Record 25 of Set 11 | beaune
# Processing Record 26 of Set 11 | egvekinot
# Processing Record 27 of Set 11 | greenville
# Processing Record 28 of Set 11 | ust-ordynskiy
# Processing Record 29 of Set 11 | tranas
# Processing Record 30 of Set 11 | pleasanton
# Processing Record 31 of Set 11 | beringovskiy
# Processing Record 32 of Set 11 | newcastleton
# Processing Record 33 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 11 | hirado
# Processing Record 35 of Set 11 | brokopondo
# Processing Record 36 of Set 11 | batagay
# Processing Record 37 of Set 11 | laurel
# Processing Record 38 of Set 11 | statesville
# Processing Record 39 of Set 11 | tikrit
# Processing Record 40 of Set 11 | iisalmi
# Processing Record 41 of Set 11 | lahij
# Processing Record 42 of Set 11 | derzhavinsk
# Processing Record 43 of Set 11 | kyren
# Processing Record 44 of Set 11 | kapit
# Processing Record 45 of Set 11 | altay
# Processing Record 46 of Set 11 | waseca
# Processing Record 47 of Set 11 | nantucket
# Processing Record 48 of Set 11 | cadillac
# Processing Record 49 of Set 11 | sfantu gheorghe
# Processing Record 0 of Set 12 | kundiawa
# Processing Record 1 of Set 12 | gornopravdinsk
# Processing Record 2 of Set 12 | bhandara
# Processing Record 3 of Set 12 | wadi musa
# Processing Record 4 of Set 12 | charters towers
# Processing Record 5 of Set 12 | ustka
# Processing Record 6 of Set 12 | sawakin
# Processing Record 7 of Set 12 | severo-kurilsk
# Processing Record 8 of Set 12 | rameswaram
# Processing Record 9 of Set 12 | guerrero negro
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | antofagasta
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | bauta
# Processing Record 14 of Set 12 | nsanje
# Processing Record 15 of Set 12 | xuchang
# Processing Record 16 of Set 12 | todos santos
# Processing Record 17 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 12 | bataipora
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | yaring
# Processing Record 24 of Set 12 | isiro
# Processing Record 25 of Set 12 | chivilcoy
# Processing Record 26 of Set 12 | mandalgovi
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | novocheremshansk
# Processing Record 29 of Set 12 | emirdag
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | ryomgard
# Processing Record 33 of Set 12 | khudumelapye
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | gifhorn
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | kalabo
# Processing Record 40 of Set 12 | arcata
# Processing Record 41 of Set 12 | lemoore
# Processing Record 42 of Set 12 | norfolk
# Processing Record 43 of Set 12 | juba
# Processing Record 44 of Set 12 | pali
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | bulgan
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | saryg-sep
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | changli
# Processing Record 7 of Set 13 | choma
# Processing Record 8 of Set 13 | tena
# Processing Record 9 of Set 13 | ilhabela
# Processing Record 10 of Set 13 | redmond
# Processing Record 11 of Set 13 | wyndham
# Processing Record 12 of Set 13 | nhulunbuy
# Processing Record 13 of Set 13 | sangamner
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | staryy nadym
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | tatarsk
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  happy valley-goose bay  53.3168  -60.3315     32.31        37          75
# 1                  kodiak  57.7900 -152.4072     36.91        52           0
# 2               vorgashor  67.5833   63.9500     20.71        79         100
# 3               kyaikkami  16.0800   97.5675     84.47        71         100
# 4               papatowai -46.5619  169.4708     52.72        75          22
#
#    Wind Speed Country        Date
# 0       16.11      CA  1744234186
# 1        6.91      US  1744234187
# 2       18.48      RU  1744234189
# 3        6.46      MM  1744234190
# 4        6.06      NZ  1744234192

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        happy valley-goose bay  53.3168  -60.3315     32.31        37
# 1                        kodiak  57.7900 -152.4072     36.91        52
# 2                     vorgashor  67.5833   63.9500     20.71        79
# 3                     kyaikkami  16.0800   97.5675     84.47        71
# 4                     papatowai -46.5619  169.4708     52.72        75
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       16.11      CA  1744234186
# 1                 0        6.91      US  1744234187
# 2               100       18.48      RU  1744234189
# 3               100        6.46      MM  1744234190
# 4                22        6.06      NZ  1744234192

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    color="gold",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    color="gold",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    color="gray",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    color="orange",
    edgecolor="black",
    linewidths=1,
    marker="o",
    label="Cities",
    s=50
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%m-%d-%Y"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates, color):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values, y_values, color=color, edgecolor="black", s=50)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitiude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        happy valley-goose bay  53.3168  -60.3315     32.31        37
# 1                        kodiak  57.7900 -152.4072     36.91        52
# 2                     vorgashor  67.5833   63.9500     20.71        79
# 3                     kyaikkami  16.0800   97.5675     84.47        71
# 5                     ilulissat  69.2167  -51.1000     28.42        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75       16.11      CA  1744234186
# 1                 0        6.91      US  1744234187
# 2               100       18.48      RU  1744234189
# 3               100        6.46      MM  1744234190
# 5               100       12.66      GL  1744234193

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <= 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4         papatowai -46.5619  169.4708     52.72        75          22
# 10           waiuku -37.2500  174.7500     60.46        56          17
# 11        grytviken -54.2811  -36.5092     43.65        81          32
# 14       bredasdorp -34.5322   20.0403     62.37        87          49
# 16           namibe -15.1961   12.1522     70.70        78          15
#
#          Wind Speed Country        Date
# City_ID
# 4              6.06      NZ  1744234192
# 10             3.71      NZ  1744234200
# 11             6.29      GS  1744234201
# 14             4.12      ZA  1744234205
# 16             6.78      AO  1744234207

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6,-10), "gold")
# Out:
# The r-value is: 0.747804729282315

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp",(-55,90), "gold")
# Out:
# The r-value is: 0.6036993734951269

# %% [markdown]
# **Discussion about the linear relationship:** The high r value shows a strong positive correlation between latitude and max temperature.
# R values ~ 0.6 indicate there is a moderate positive correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50,18), "pink")
# Out:
# The r-value is: 0.01901586261545136

# %%
# Southern Hemisphere
# Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-20,35), "pink")
# Out:
# The r-value is: 0.0709646581285866

# %% [markdown]
# **Discussion about the linear relationship:** The above graphs and R value demonstrate there is little correlation between humidity and latitude (r ~ 1 is little to no correlation)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (50,50), "gray")
# Out:
# The r-value is: 0.021933105069437995

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-55,20), "gray")
# Out:
# The r-value is: 0.062001681810878014

# %% [markdown]
# **Discussion about the linear relationship:** The R value demonstrates there is a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (50,35), "orange")
# Out:
# The r-value is: 0.019693047734922028

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-30,30), "orange")
# Out:
# The r-value is: 0.061956159950690703

# %% [markdown]
# **Discussion about the linear relationship:** The R values being below 1, demonstrate again there is low correlation between latitiude and wind speed.
